# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximRubbit2/MALLlblHa/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/global-data-on-sustainable-energy (1).csv')
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
df.head(0)

# %%
df.head(5)
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
df.tail(5)
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 3644  Zimbabwe  2016                                42.561730
# 3645  Zimbabwe  2017                                44.178635
# 3646  Zimbabwe  2018                                45.572647
# 3647  Zimbabwe  2019                                46.781475
# 3648  Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 3644                               29.8
# 3645                               29.8
# 3646                               29.9
# 3647                               30.1
# 3648                               30.4
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 3644                                              62.88
# 3645                                              62.33
# 3646                                              82.53
# 3647                                              81.40
# 3648                                              80.61
# ...

# %%
df.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %%
df.mean()
# Out:
# <ipython-input-12-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Year                                                                2.010038e+03
# Access to electricity (% of population)                             7.893370e+01
# Access to clean fuels for cooking                                   6.325529e+01
# Renewable-electricity-generating-capacity-per-capita                1.131375e+02
# Financial flows to developing countries (US $)                      9.422400e+07
# Renewable energy share in the total final energy consumption (%)    3.263816e+01
# Electricity from fossil fuels (TWh)                                 7.036500e+01
# Electricity from nuclear (TWh)                                      1.345019e+01
# ...

# %%
df.min()
# Out:
# <ipython-input-13-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Entity                                                              Afghanistan
# Year                                                                       2000
# Access to electricity (% of population)                                1.252269
# Access to clean fuels for cooking                                           0.0
# Renewable-electricity-generating-capacity-per-capita                        0.0
# Financial flows to developing countries (US $)                              0.0
# Renewable energy share in the total final energy consumption (%)            0.0
# Electricity from fossil fuels (TWh)                                         0.0
# ...

# %%
df.max()
# Out:
# <ipython-input-14-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Entity                                                                  Zimbabwe
# Year                                                                        2020
# Access to electricity (% of population)                                    100.0
# Access to clean fuels for cooking                                          100.0
# Renewable-electricity-generating-capacity-per-capita                     3060.19
# Financial flows to developing countries (US $)                      5202310000.0
# Renewable energy share in the total final energy consumption (%)           96.04
# Electricity from fossil fuels (TWh)                                      5184.13
# ...

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.Year = df.Year.astype("category")
df.Year
# Out:
# 0       2000
# 1       2001
# 2       2002
# 3       2003
# 4       2004
#         ...
# 3644    2016
# 3645    2017
# 3646    2018
# 3647    2019
# 3648    2020
# Name: Year, Length: 3649, dtype: category
# Categories (21, int64): [2000, 2001, 2002, 2003, ..., 2017, 2018, 2019, 2020]

# %%
koko = 'Access to electricity (% of population)'
df[koko] = df[koko].dropna().astype("float")
df[koko]
# Out:
# 0        1.0
# 1        4.0
# 2        9.0
# 3       14.0
# 4       20.0
#         ...
# 3644    42.0
# 3645    44.0
# 3646    45.0
# 3647    46.0
# 3648    52.0
# Name: Access to electricity (% of population), Length: 3649, dtype: float64

# %%
pok = 'gdp_growth'
df[pok] = df[pok].dropna().astype("int")
df[pok]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       8.0
# 4       1.0
#        ...
# 3644    0.0
# 3645    4.0
# 3646    4.0
# 3647   -6.0
# 3648   -6.0
# Name: gdp_growth, Length: 3649, dtype: float64

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df[df["Renewable-electricity-generating-capacity-per-capita"] > 2000]
# Out:
#      Entity  Year  Access to electricity (% of population)  \
# 427  Bhutan  2007                                     71.0
# 428  Bhutan  2008                                     67.0
# 429  Bhutan  2009                                     71.0
# 430  Bhutan  2010                                     73.0
# 431  Bhutan  2011                                     81.0
# 432  Bhutan  2012                                     91.0
# 433  Bhutan  2013                                     87.0
# 434  Bhutan  2014                                     91.0
# 435  Bhutan  2015                                     95.0
# 436  Bhutan  2016                                     99.0
# 437  Bhutan  2017                                     97.0
# 438  Bhutan  2018                                     99.0
# 439  Bhutan  2019                                    100.0
# 440  Bhutan  2020                                    100.0
#
#      Access to clean fuels for cooking  \
# ...

# %%
df[df["gdp_growth"] == 8]
# Out:
#                     Entity  Year  Access to electricity (% of population)  \
# 3              Afghanistan  2003                                     14.0
# 22                 Albania  2001                                    100.0
# 75                  Angola  2012                                     37.0
# 108              Argentina  2003                                     96.0
# 110              Argentina  2005                                     96.0
# ...                    ...   ...                                      ...
# 3446               Ukraine  2007                                     99.0
# 3463  United Arab Emirates  2003                                    100.0
# 3553            Uzbekistan  2009                                     99.0
# 3571               Vanuatu  2006                                     26.0
# 3614                Zambia  2007                                     18.0
#
#       Access to clean fuels for cooking  \
# ...

# %%
df[df["Latitude"] <= 0]
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 63      Angola  2000                                     24.0
# 64      Angola  2001                                     20.0
# 65      Angola  2002                                     26.0
# 66      Angola  2003                                     27.0
# 67      Angola  2004                                     28.0
# ...        ...   ...                                      ...
# 3644  Zimbabwe  2016                                     42.0
# 3645  Zimbabwe  2017                                     44.0
# 3646  Zimbabwe  2018                                     45.0
# 3647  Zimbabwe  2019                                     46.0
# 3648  Zimbabwe  2020                                     52.0
#
#       Access to clean fuels for cooking  \
# 63                                 41.1
# 64                                 41.7
# 65                                 41.7
# 66                                 42.0
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby(["Year"]).count()
# Out:
#       Entity  Access to electricity (% of population)  \
# Year
# 2000     173                                      170
# 2001     172                                      170
# 2002     172                                      171
# 2003     172                                      171
# 2004     172                                      171
# 2005     172                                      171
# 2006     172                                      171
# 2007     174                                      174
# 2008     174                                      174
# 2009     174                                      174
# 2010     174                                      174
# 2011     174                                      174
# 2012     174                                      174
# 2013     175                                      175
# 2014     175                                      175
# 2015     175                                      175
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
