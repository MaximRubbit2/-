# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximRubbit2/MALLlblHa/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 2

# %%
# !pip install pandas
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Введение в описательную статистику

# %% [markdown]
# 1. Выберите категориальную целевую переменную (**Y**)
#
# 2. Выберите переменную для анализа относительно категории (**X**)
#
# 3. Выведитие обобщенную статистическую информацию переменной (**X**)
#
# 2. Вычислите среднее, медиану, моду, минимум, максимум, стандартное отклонение относительно целевой пременной из файла Classification datasets в соответствии с вашим вариантом
#
# 3. Сделайте вывод относительно полученных результатов
#
# p.s если у вас нет категориальных признаков - преобразуйте любой числовой в категориальный (https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Важно **не** использовать преобразованный Y вместе с этим же X (то есть, если вы преобразовали возраст в категорию, то вы не моежет использовать возраст в качестве X и возраст категорию в качестве Y)

# %%
df = pd.read_csv('/content/global-data-on-sustainable-energy (1).csv')
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
describe = pd.read_csv('/content/global-data-on-sustainable-energy (1).csv')

# %%
mean = df['Access to clean fuels for cooking'].mean ()
print("Среднее:", mean)
# Out:
# Среднее: 63.25528735632183

# %%
median = df['Access to clean fuels for cooking'].median()
print("Медиана:",median)
# Out:
# Медиана: 83.15

# %%
mode = df['Access to clean fuels for cooking'].mode()
print("Мода:",mode)
# Out:
# Мода: 0    100.0
# Name: Access to clean fuels for cooking, dtype: float64

# %%
min = df['Access to clean fuels for cooking'].min()
print("Минимум:",min)
# Out:
# Минимум: 0.0

# %%
max = df['Access to clean fuels for cooking'].max()
print("Максимум:",max)
# Out:
# Максимум: 100.0

# %%
std = df['Access to clean fuels for cooking'].std()
print("Стандартное отклонение:",std)
# Out:
# Стандартное отклонение: 39.04365757473373

# %% [markdown]
# Вычислите следующие квантили: 25%, 50% (медиана), 75% для числового признака вашего датасета. Затем найдите интерквартильный размах.

# %%
q1 = df['Access to clean fuels for cooking'].quantile(0.25)
print("Первый квантиль (25%):", q1)
# Out:
# Первый квантиль (25%): 23.175

# %%
q2 = df['Access to clean fuels for cooking'].quantile(0.50)
print("Второй квантиль (медиана) (50%):", q2)
# Out:
# Второй квантиль (медиана) (50%): 83.15

# %%
q3 = df['Access to clean fuels for cooking'].quantile(0.75)
print("Третий квантиль (75%):", q3)
# Out:
# Третий квантиль (75%): 100.0

# %%
iqr = q3 - q1
print("Интерквартильный размах:", iqr)
# Out:
# Интерквартильный размах: 76.825

# %% [markdown]
# Какие выводы можно сделать исходя из полученных статистических данных?

# %% [markdown]
# **Ответ здесь**
#
# ```
# Среднее значение (63.26) указывает на средний уровень набора данных.
# Медиана (83.15) выше среднего, что может свидетельствовать о том, что распределение данных имеет положительную асимметрию.
# Мода (100.0) является самым часто встречающимся значением и равна максимальному значению, что может указывать на наличие выбросов или на то, что максимальные значения встречаются очень часто.
# Минимальное значение (0.0) и максимальное значение (100.0) показывают полный диапазон данных.
# Стандартное отклонение (39.04) довольно велико, что указывает на значительное разброс данных относительно среднего значения.
# Первый квантиль (23.175) и третий квантиль (100.0) показывают, что 25% данных находятся ниже 23.175, а 75% данных - ниже 100.0.
# Интерквартильный размах (76.825) большой, что также указывает на значительный разброс между первым и третьим квантилями.
# Эти данные могут быть полезны для анализа распределения и вариативности в наборе данных, а также для выявления потенциальных выбросов или аномалий. Они также могут помочь в определении, следует ли использовать среднее значение или медиану для представления “типичного” значения в данных. В данном случае, учитывая большое стандартное отклонение и разницу между средним и медианой, медиана может быть более надежным показателем центральной тенденции.
# ```

# %% [markdown]
# ##Основы визуализации

# %% [markdown]
#  Постройте гистограмму переменной (X) относительно категориального признака (Y) из своего датасета.

# %%
plt.figure(figsize=(5, 3))
plt.hist(df['Access to clean fuels for cooking'], bins=10, edgecolor='black')
plt.title('Гистограмма доступа к чистому топливу')
plt.xlabel('Доступ к чистому топливу')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Постройте boxplot любого признака из своего датасета.
#
# 1) boxplot числовой переменной;
#
# 2) boxplot числовой переменной относительно категориальный переменной;
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Access to clean fuels for cooking_encoded'] = label_encoder.fit_transform(df['Access to clean fuels for cooking'])
plt.figure(figsize=(5, 3))
plt.boxplot(df['Access to clean fuels for cooking_encoded'])
plt.title('Boxplot доступа к чистому топливу')
plt.xlabel('Доступ к чистому топливу')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Access to clean fuels for cooking_encoded'] = label_encoder.fit_transform(df['Access to clean fuels for cooking'])
plt.figure(figsize=(4, 3))
sns.boxplot(df['Access to clean fuels for cooking_encoded'], color='turquoise')
plt.title('Boxplot доступа к чистому топливу с Seaborn')
plt.xlabel('Доступ к чистому топливу')
plt.show()

# %% [markdown]
# Постройте диаграмму рассеивания для числовых признаков вашего датасета.
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Access to clean fuels for cooking_encoded'] = label_encoder.fit_transform(df['Access to clean fuels for cooking'])
df['Access to electricity (% of population)_encoded'] = label_encoder.fit_transform(df['Access to electricity (% of population)'])
plt.figure(figsize=(4, 3))
plt.scatter(df['Access to clean fuels for cooking_encoded'], df['Access to electricity (% of population)'], color='purple')
plt.title('Диаграмма рассеивания для доступа к топливу и доступа к электричеству')
plt.xlabel('Доступ к топливу')
plt.ylabel('Доступ к электричеству')
plt.show()

# %% [markdown]
# Постройте матрицу корреляции для двух числовых признаков вашего датасета.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <ipython-input-93-c56d7301fe57>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# <Axes: >

# %% [markdown]
# Какие выводы можно сделать на основе графиков и матрицы корреляции?

# %% [markdown]
# **Ответ здесь**
#
# 1.) По гистограмме можно определить следущее:
# Бимодальное распределение: Наличие двух “пиков” в данных, один в начале диапазона (0-10) и один в конце (90-100), что может свидетельствовать о двух различных группах внутри набора данных.
# Неравномерное распределение: Большинство значений сосредоточено в начале и в конце диапазона, а между ними — значительно меньше значений.
# Возможные выбросы или аномалии: Особенно высокие значения в конце диапазона (90-100) могут быть выбросами или особыми случаями, которые стоит дополнительно исследовать.
#
# 2.) Boxplot доступа к чистому топливу.
# Большинство значений сосредоточено в нижней части диапазона, а меньшее количество значений — в верхней части.
# Для boxplot доступа к чистому топливу в большинстве случаев доступ ограничен, но есть несколько случаев с очень высоким уровнем доступа, которые поднимают среднее значение. Это может быть полезно для выявления областей с особенно хорошим или плохим доступом к чистому топливу и для планирования мер по улучшению ситуации.
#
# 3.) Boxplot с Seaborn аналогичная ситуация с Boxplot.
#
# 4.) На диаграмме рассеивания для доступа к топливу и доступа к электричеству можно увидеть что доступ к топливу больше, чем к электричеству.

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать следующие методы поиска выбросов:
# 1. На основе среднего и отклонения
# 2. Критерий Шовене
# 3. С помощью квартилей
# 4. Поиск выбросов по двум переменным
#
# [Посмотреть](http://course.omgtu.ru/wp-content/uploads/2021/04/3_%D0%92%D1%8B%D0%B1%D1%80%D0%BE%D1%81%D1%8B.pdf)
#
# P.S. в качестве возвразаемого значения методов может быть:
# 1. очищенный датафрейм
# 2. индексы выбросов ```df.series.index```

# %%
"""

Ваш код здесь

"""

# %% [markdown]
# ### Пример реализации одного метода

# %%
from statistics import median, mean

class Outline:
  def __init__(self, df):
    self.df = df

  def delete_outline_by_mean(self, column_name):
    mean_data = mean(self.df[column_name])
    maximum = mean_data * 2
    result = []

    for item in self.df[column_name]:
      if abs(item - mean_data) < maximum:
        result.append(item)

    return result

# %%
data = pd.DataFrame(
    data = {
        "col1": [1, 2, 3, 4, 5, 1000],
        "col2": [1, 2, 3, 2, 1, 4]
    }
)

so = Outline(data)
so.delete_outline_by_mean("col1")
# Out:
# [1, 2, 3, 4, 5]
